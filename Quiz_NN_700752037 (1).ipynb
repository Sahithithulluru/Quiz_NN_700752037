# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# Load the Air Passengers dataset
data = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv')

# %%
print(data.head())
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
# Convert 'Month' column to datetime
data['Month'] = pd.to_datetime(data['Month'])

# Set 'Month' column as index
data.set_index('Month', inplace=True)

# Plot the original time series data
plt.figure(figsize=(10, 6))
plt.plot(data)
plt.title('Air Passengers Time Series')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.show()

# Split the data into training and testing sets (80% train, 20% test)
train_size = int(len(data) * 0.8)
test_size = len(data) - train_size
train, test = data.iloc[:train_size], data.iloc[train_size:]

print("Training set size:", len(train))
print("Testing set size:", len(test))
# Out:
# Training set size: 115
# Testing set size: 29

# %%
# Scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.transform(test)

# %%
def create_sequences(data, lookback):
    X, y = [], []
    for i in range(len(data) - lookback):
        X.append(data[i:(i + lookback), 0])
        y.append(data[i + lookback, 0])
    return np.array(X), np.array(y)

# Define the lookback window size
lookback = 12

# Create training and testing sequences
X_train, y_train = create_sequences(train_scaled, lookback)
X_test, y_test = create_sequences(test_scaled, lookback)

# Reshape input data to be 3D (samples, timesteps, features)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
# Define the LSTM model
model = Sequential([
    LSTM(units=50, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dense(units=1)
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 6s 423ms/step - loss: 0.2348 - val_loss: 0.8605
# Epoch 2/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.1528 - val_loss: 0.5785
# Epoch 3/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0914 - val_loss: 0.3486
# Epoch 4/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0472 - val_loss: 0.1699
# Epoch 5/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0201 - val_loss: 0.0642
# Epoch 6/100
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0180 - val_loss: 0.0427
# Epoch 7/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0247 - val_loss: 0.0436
# Epoch 8/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0186 - val_loss: 0.0565
# Epoch 9/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0147 - val_loss: 0.0792
# Epoch 10/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0155 - val_loss: 0.0928
# Epoch 11/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0163 - val_loss: 0.0883
# Epoch 12/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0153 - val_loss: 0.0724
# Epoch 13/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0133 - val_loss: 0.0543
# Epoch 14/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0127 - val_loss: 0.0455
# Epoch 15/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0136 - val_loss: 0.0440
# Epoch 16/100
# 4/4 [==============================] - 0s 77ms/step - loss: 0.0135 - val_loss: 0.0448
# Epoch 17/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0123 - val_loss: 0.0482
# Epoch 18/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0530
# Epoch 19/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0125 - val_loss: 0.0542
# Epoch 20/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0120 - val_loss: 0.0469
# Epoch 21/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0115 - val_loss: 0.0436
# Epoch 22/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0117 - val_loss: 0.0430
# Epoch 23/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0119 - val_loss: 0.0428
# Epoch 24/100
# 4/4 [==============================] - 0s 67ms/step - loss: 0.0118 - val_loss: 0.0427
# Epoch 25/100
# 4/4 [==============================] - 0s 99ms/step - loss: 0.0114 - val_loss: 0.0430
# Epoch 26/100
# 4/4 [==============================] - 0s 102ms/step - loss: 0.0113 - val_loss: 0.0430
# Epoch 27/100
# 4/4 [==============================] - 0s 130ms/step - loss: 0.0111 - val_loss: 0.0419
# Epoch 28/100
# 4/4 [==============================] - 0s 65ms/step - loss: 0.0118 - val_loss: 0.0422
# Epoch 29/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0112 - val_loss: 0.0418
# Epoch 30/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0110 - val_loss: 0.0448
# Epoch 31/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0111 - val_loss: 0.0444
# Epoch 32/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0109 - val_loss: 0.0412
# Epoch 33/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0108 - val_loss: 0.0404
# Epoch 34/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0107 - val_loss: 0.0408
# Epoch 35/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0107 - val_loss: 0.0424
# Epoch 36/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0107 - val_loss: 0.0422
# Epoch 37/100
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0106 - val_loss: 0.0415
# Epoch 38/100
# 4/4 [==============================] - 0s 63ms/step - loss: 0.0105 - val_loss: 0.0408
# Epoch 39/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0104 - val_loss: 0.0403
# Epoch 40/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0105 - val_loss: 0.0403
# Epoch 41/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0101 - val_loss: 0.0383
# Epoch 42/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0106 - val_loss: 0.0380
# Epoch 43/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0108 - val_loss: 0.0380
# Epoch 44/100
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0106 - val_loss: 0.0422
# Epoch 45/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0102 - val_loss: 0.0402
# Epoch 46/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0100 - val_loss: 0.0387
# Epoch 47/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0099 - val_loss: 0.0382
# Epoch 48/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0099 - val_loss: 0.0386
# Epoch 49/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0098 - val_loss: 0.0397
# Epoch 50/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0098 - val_loss: 0.0399
# Epoch 51/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0098 - val_loss: 0.0388
# Epoch 52/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0097 - val_loss: 0.0364
# Epoch 53/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0098 - val_loss: 0.0367
# Epoch 54/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0096 - val_loss: 0.0370
# Epoch 55/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0095 - val_loss: 0.0382
# Epoch 56/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0094 - val_loss: 0.0370
# Epoch 57/100
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0095 - val_loss: 0.0361
# Epoch 58/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0093 - val_loss: 0.0398
# Epoch 59/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0094 - val_loss: 0.0405
# Epoch 60/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0093 - val_loss: 0.0384
# Epoch 61/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0091 - val_loss: 0.0361
# Epoch 62/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0092 - val_loss: 0.0356
# Epoch 63/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0092 - val_loss: 0.0367
# Epoch 64/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0089 - val_loss: 0.0378
# Epoch 65/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0089 - val_loss: 0.0363
# Epoch 66/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0088 - val_loss: 0.0338
# Epoch 67/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0090 - val_loss: 0.0338
# Epoch 68/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0087 - val_loss: 0.0366
# Epoch 69/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0087 - val_loss: 0.0386
# Epoch 70/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0088 - val_loss: 0.0344
# Epoch 71/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0087 - val_loss: 0.0354
# Epoch 72/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0085 - val_loss: 0.0328
# Epoch 73/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0086 - val_loss: 0.0320
# Epoch 74/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0086 - val_loss: 0.0333
# Epoch 75/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0083 - val_loss: 0.0336
# Epoch 76/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0082 - val_loss: 0.0377
# Epoch 77/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0085 - val_loss: 0.0420
# Epoch 78/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0084 - val_loss: 0.0358
# Epoch 79/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0081 - val_loss: 0.0302
# Epoch 80/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0083 - val_loss: 0.0327
# Epoch 81/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0077 - val_loss: 0.0399
# Epoch 82/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0079 - val_loss: 0.0400
# Epoch 83/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0079 - val_loss: 0.0327
# Epoch 84/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0076 - val_loss: 0.0341
# Epoch 85/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0076 - val_loss: 0.0300
# Epoch 86/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0077 - val_loss: 0.0266
# Epoch 87/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0083 - val_loss: 0.0319
# Epoch 88/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0377
# Epoch 89/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0074 - val_loss: 0.0339
# Epoch 90/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0073 - val_loss: 0.0274
# Epoch 91/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0075 - val_loss: 0.0360
# Epoch 92/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0072 - val_loss: 0.0344
# Epoch 93/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0067 - val_loss: 0.0267
# Epoch 94/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0073 - val_loss: 0.0266
# Epoch 95/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0070 - val_loss: 0.0378
# Epoch 96/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0069 - val_loss: 0.0361
# Epoch 97/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0066 - val_loss: 0.0272
# Epoch 98/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0068 - val_loss: 0.0228
# Epoch 99/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0073 - val_loss: 0.0258
# Epoch 100/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0063 - val_loss: 0.0403

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0073 - val_loss: 0.0259
# Epoch 2/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0065 - val_loss: 0.0213
# Epoch 3/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0066 - val_loss: 0.0306
# Epoch 4/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0060 - val_loss: 0.0237
# Epoch 5/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0059 - val_loss: 0.0261
# Epoch 6/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0058 - val_loss: 0.0284
# Epoch 7/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0056 - val_loss: 0.0237
# Epoch 8/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0057 - val_loss: 0.0292
# Epoch 9/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0055 - val_loss: 0.0269
# Epoch 10/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0055 - val_loss: 0.0298
# Epoch 11/100
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0052 - val_loss: 0.0224
# Epoch 12/100
# 4/4 [==============================] - 0s 68ms/step - loss: 0.0054 - val_loss: 0.0246
# Epoch 13/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0053 - val_loss: 0.0307
# Epoch 14/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0338
# Epoch 15/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0265
# Epoch 16/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0345
# Epoch 17/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0051 - val_loss: 0.0298
# Epoch 18/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0196
# Epoch 19/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0054 - val_loss: 0.0323
# Epoch 20/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0052 - val_loss: 0.0282
# Epoch 21/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0247
# Epoch 22/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0381
# Epoch 23/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0042 - val_loss: 0.0241
# Epoch 24/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0337
# Epoch 25/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0256
# Epoch 26/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0039 - val_loss: 0.0299
# Epoch 27/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 0.0291
# Epoch 28/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0247
# Epoch 29/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0038 - val_loss: 0.0374
# Epoch 30/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0041 - val_loss: 0.0309
# Epoch 31/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0033 - val_loss: 0.0396
# Epoch 32/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0038 - val_loss: 0.0317
# Epoch 33/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0327
# Epoch 34/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0032 - val_loss: 0.0327
# Epoch 35/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0033 - val_loss: 0.0276
# Epoch 36/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0033 - val_loss: 0.0285
# Epoch 37/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0275
# Epoch 38/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0033 - val_loss: 0.0394
# Epoch 39/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0035 - val_loss: 0.0289
# Epoch 40/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0028 - val_loss: 0.0303
# Epoch 41/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0027 - val_loss: 0.0411
# Epoch 42/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0028 - val_loss: 0.0318
# Epoch 43/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0027 - val_loss: 0.0414
# Epoch 44/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0026 - val_loss: 0.0264
# Epoch 45/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0026 - val_loss: 0.0288
# Epoch 46/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0286
# Epoch 47/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0024 - val_loss: 0.0393
# Epoch 48/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0025 - val_loss: 0.0292
# Epoch 49/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0469
# Epoch 50/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0024 - val_loss: 0.0176
# Epoch 51/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0034 - val_loss: 0.0614
# Epoch 52/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0035 - val_loss: 0.0282
# Epoch 53/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0031 - val_loss: 0.0219
# Epoch 54/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0028 - val_loss: 0.0366
# Epoch 55/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0024 - val_loss: 0.0199
# Epoch 56/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0024 - val_loss: 0.0481
# Epoch 57/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0026 - val_loss: 0.0172
# Epoch 58/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0033 - val_loss: 0.0551
# Epoch 59/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0234
# Epoch 60/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0033 - val_loss: 0.0233
# Epoch 61/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0034 - val_loss: 0.0383
# Epoch 62/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0027 - val_loss: 0.0153
# Epoch 63/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0032 - val_loss: 0.0609
# Epoch 64/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0036 - val_loss: 0.0137
# Epoch 65/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0033 - val_loss: 0.0507
# Epoch 66/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0031 - val_loss: 0.0170
# Epoch 67/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0268
# Epoch 68/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 0.0297
# Epoch 69/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0022 - val_loss: 0.0254
# Epoch 70/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0023 - val_loss: 0.0339
# Epoch 71/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0023 - val_loss: 0.0311
# Epoch 72/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0023 - val_loss: 0.0317
# Epoch 73/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0021 - val_loss: 0.0296
# Epoch 74/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0020 - val_loss: 0.0346
# Epoch 75/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0020 - val_loss: 0.0271
# Epoch 76/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0020 - val_loss: 0.0260
# Epoch 77/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0019 - val_loss: 0.0393
# Epoch 78/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 0.0268
# Epoch 79/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0019 - val_loss: 0.0375
# Epoch 80/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0019 - val_loss: 0.0282
# Epoch 81/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0027 - val_loss: 0.0730
# Epoch 82/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0037 - val_loss: 0.0140
# Epoch 83/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0030 - val_loss: 0.0639
# Epoch 84/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0037 - val_loss: 0.0110
# Epoch 85/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0454
# Epoch 86/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0126
# Epoch 87/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0031 - val_loss: 0.0399
# Epoch 88/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0021 - val_loss: 0.0169
# Epoch 89/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0022 - val_loss: 0.0268
# Epoch 90/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0020 - val_loss: 0.0192
# Epoch 91/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0019 - val_loss: 0.0211
# Epoch 92/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0020 - val_loss: 0.0237
# Epoch 93/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0020 - val_loss: 0.0172
# Epoch 94/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0025 - val_loss: 0.0273
# Epoch 95/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0020 - val_loss: 0.0201
# Epoch 96/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0024 - val_loss: 0.0300
# Epoch 97/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0023 - val_loss: 0.0173
# Epoch 98/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0024 - val_loss: 0.0421
# Epoch 99/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0034 - val_loss: 0.0167
# Epoch 100/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0025 - val_loss: 0.0403

# %%
# Predict on testing data
y_pred = model.predict(X_test)

# Invert scaling to get original values
y_pred = scaler.inverse_transform(y_pred)
y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate MSE and RMSE
mse = mean_squared_error(y_test_orig, y_pred)
rmse = np.sqrt(mse)

print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# 1/1 [==============================] - 1s 532ms/step
# Mean Squared Error (MSE): 6033.758226952296
# Root Mean Squared Error (RMSE): 77.67726969295649

# %%
# Plot the predicted vs. actual values
plt.figure(figsize=(10, 6))
plt.plot(y_test_orig, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('Air Passengers Forecasting - LSTM')
plt.xlabel('Time')
plt.ylabel('Number of Passengers')
plt.legend()
plt.show()

# %%
# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the predicted vs. actual values
plt.figure(figsize=(10, 6))
plt.plot(y_test_orig, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('Air Passengers Forecasting - LSTM')
plt.xlabel('Time')
plt.ylabel('Number of Passengers')
plt.legend()
plt.show()

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#Image Classification

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau

# Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Preprocess the data
X_train = X_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
X_test = X_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# Build the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Define ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.0001)

# Train the model
history = model.fit(X_train, y_train, batch_size=128, epochs=10, validation_data=(X_test, y_test), callbacks=[reduce_lr])
# Out:
# Epoch 1/10
# 469/469 [==============================] - 46s 95ms/step - loss: 0.2204 - accuracy: 0.9355 - val_loss: 0.0678 - val_accuracy: 0.9776 - lr: 0.0010
# Epoch 2/10
# 469/469 [==============================] - 40s 85ms/step - loss: 0.0593 - accuracy: 0.9816 - val_loss: 0.0506 - val_accuracy: 0.9829 - lr: 0.0010
# Epoch 3/10
# 469/469 [==============================] - 41s 88ms/step - loss: 0.0412 - accuracy: 0.9869 - val_loss: 0.0400 - val_accuracy: 0.9872 - lr: 0.0010
# Epoch 4/10
# 469/469 [==============================] - 41s 87ms/step - loss: 0.0311 - accuracy: 0.9904 - val_loss: 0.0329 - val_accuracy: 0.9893 - lr: 0.0010
# Epoch 5/10
# 469/469 [==============================] - 41s 86ms/step - loss: 0.0251 - accuracy: 0.9921 - val_loss: 0.0276 - val_accuracy: 0.9909 - lr: 0.0010
# Epoch 6/10
# 469/469 [==============================] - 41s 88ms/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 0.0326 - val_accuracy: 0.9892 - lr: 0.0010
# Epoch 7/10
# 469/469 [==============================] - 42s 89ms/step - loss: 0.0161 - accuracy: 0.9949 - val_loss: 0.0320 - val_accuracy: 0.9901 - lr: 0.0010
# Epoch 8/10
# 469/469 [==============================] - 41s 88ms/step - loss: 0.0133 - accuracy: 0.9954 - val_loss: 0.0314 - val_accuracy: 0.9915 - lr: 0.0010
# Epoch 9/10
# 469/469 [==============================] - 41s 87ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.0270 - val_accuracy: 0.9921 - lr: 2.0000e-04
# Epoch 10/10
# 469/469 [==============================] - 40s 86ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.0276 - val_accuracy: 0.9923 - lr: 2.0000e-04

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

# Visualize training history
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0276 - accuracy: 0.9923
# Test Loss: 0.027593810111284256
# Test Accuracy: 0.9922999739646912

# %%
# Evaluate the model on the test set
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

# Visualize training history
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0276 - accuracy: 0.9923
# Test Loss: 0.027593810111284256
# Test Accuracy: 0.9922999739646912
